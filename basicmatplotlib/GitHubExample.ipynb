# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_Fun = (1,2,3,4,5,6,7,8,9)
df_Fun1 = (1,3,5,7,9,11,13,15,17)

# %%
fig,ax = plt.subplots()
ax.plot(df_Fun, df_Fun1, alpha = 0.5, c = 'b')
fig.suptitle('This Graph Is For GitHub')
ax.xaxis.set_label_text('X Axis')
ax.yaxis.set_label_text('Y Axis')
plt.show()
